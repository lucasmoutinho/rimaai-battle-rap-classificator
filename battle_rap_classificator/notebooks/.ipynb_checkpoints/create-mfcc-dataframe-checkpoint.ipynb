# %%
import pandas as pd
import numpy as np
import librosa
import requests
import IPython.display

# %%
dataset_path = "../resources/dataset/dataset.csv"
dataset = pd.read_csv(dataset_path)

# %%
dataset
# Out:
#                      Token  Round  \
# 0     -MC4JosLZF9ks4ry1pSx      1
# 1     -MC4K0DO9Knkiv1JLESj      1
# 2     -MC4K0DO9Knkiv1JLESj      2
# 3     -MC4KDB6YZgs4Ok8X2Ct      1
# 4     -MC4KDB6YZgs4Ok8X2Ct      2
# ...                    ...    ...
# 2143  -MC95J9TyoUsWS5AXXdb      2
# 2144  -MC95ZIRDgUQrRYjHqu2      1
# 2145  -MC95ZIRDgUQrRYjHqu2      2
# 2146  -MC95h6At8VEYx9fBYHu      1
# 2147  -MC964kZKQGJovu7OHpn      1
#
#                                                  Ataque  \
# 0     https://firebasestorage.googleapis.com/v0/b/ra...
# 1     https://firebasestorage.googleapis.com/v0/b/ra...
# 2     https://firebasestorage.googleapis.com/v0/b/ra...
# 3     https://firebasestorage.googleapis.com/v0/b/ra...
# 4     https://firebasestorage.googleapis.com/v0/b/ra...
# ...                                                 ...
# 2143  https://firebasestorage.googleapis.com/v0/b/ra...
# 2144  https://firebasestorage.googleapis.com/v0/b/ra...
# 2145  https://firebasestorage.googleapis.com/v0/b/ra...
# 2146  https://firebasestorage.googleapis.com/v0/b/ra...
# 2147  https://firebasestorage.googleapis.com/v0/b/ra...
#
#                                                Resposta Resultado
# 0     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 1     https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 3     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 4     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# ...                                                 ...       ...
# 2143  https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 2144  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2145  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2146  https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 2147  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
#
# [2148 rows x 5 columns]

# %%
dataset = dataset.drop(["Token", "Round"], axis=1)

# %%
dataset
# Out:
#                                                  Ataque  \
# 0     https://firebasestorage.googleapis.com/v0/b/ra...
# 1     https://firebasestorage.googleapis.com/v0/b/ra...
# 2     https://firebasestorage.googleapis.com/v0/b/ra...
# 3     https://firebasestorage.googleapis.com/v0/b/ra...
# 4     https://firebasestorage.googleapis.com/v0/b/ra...
# ...                                                 ...
# 2143  https://firebasestorage.googleapis.com/v0/b/ra...
# 2144  https://firebasestorage.googleapis.com/v0/b/ra...
# 2145  https://firebasestorage.googleapis.com/v0/b/ra...
# 2146  https://firebasestorage.googleapis.com/v0/b/ra...
# 2147  https://firebasestorage.googleapis.com/v0/b/ra...
#
#                                                Resposta Resultado
# 0     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 1     https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 3     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 4     https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# ...                                                 ...       ...
# 2143  https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 2144  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2145  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
# 2146  https://firebasestorage.googleapis.com/v0/b/ra...    ataque
# 2147  https://firebasestorage.googleapis.com/v0/b/ra...  resposta
#
# [2148 rows x 3 columns]

# %%
# Testing save soundfiles from firebase
url = dataset["Ataque"][0]
audio_path = '../resources/audio_samples/soundfile.aac'
r = requests.get(url, allow_redirects=True)
open(audio_path, 'wb').write(r.content)
x, sr = librosa.load(audio_path)
IPython.display.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import warnings

def mfcc_extract(url):
    audio_path = '../resources/audio_samples/soundfile.aac'
    r = requests.get(url, allow_redirects=True)
    open(audio_path, 'wb').write(r.content)
    warnings.filterwarnings("ignore")
    x, sr = librosa.load(audio_path)
    mfccs = librosa.feature.mfcc(x, sr=sr)
    mfccs_processed = np.mean(mfccs.T,axis=0)
    return mfccs_processed

# %%
# Testing concatenation
a = mfcc_extract(dataset["Ataque"][0])
b = mfcc_extract(dataset["Resposta"][0])
c = np.concatenate([a,b])
print(c)
# Out:
# [-190.01176    102.31164    -16.247204    20.978662    -7.569092
#     5.9878836  -21.883598     1.1563772  -25.37083     -6.37719
#   -10.03182     -1.8496873  -14.903586     3.527926    -9.699288
#    -4.6196303   -8.374349     4.1147685  -17.340984    -4.553175
#  -105.07531     65.86335    -68.66974     21.781288   -16.206564
#     1.0610797  -20.418556    15.674933   -21.640335     1.4478163
#   -14.121316     2.3780205  -23.332838     7.798318   -13.541758
#     0.6557746   -7.101304     9.495758   -26.047287     0.962551 ]

# %%
features = []
idx = 0
for a_url, r_url, result in zip(dataset["Ataque"], dataset["Resposta"], dataset["Resultado"]):
    features.append([np.concatenate([mfcc_extract(a_url), mfcc_extract(r_url)]), result])
    if(idx % 100 == 0):
        print(idx)
    idx = idx + 1
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100

# %%
df = pd.DataFrame(features, columns=['feature','class_label'])

# %%
df.head()
# Out:
#                                              feature class_label
# 0  [-190.01157, 102.312195, -16.247314, 20.979342...      ataque
# 1  [-96.46623, 90.81202, -59.434887, 47.461735, -...    resposta
# 2  [-298.91815, 137.08705, -30.425154, 51.051403,...      ataque
# 3  [-131.61105, 102.911446, -49.566418, 51.990337...      ataque
# 4  [-140.60637, 120.30431, 15.799376, 25.646097, ...      ataque

# %%
df.to_csv("../resources/dataset/dataset_mfccs.csv")
